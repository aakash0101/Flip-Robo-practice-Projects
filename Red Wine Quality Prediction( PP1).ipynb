# %%
#importing libraries and modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Dataset
wineData = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
wineData
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Display total no. of rows and columns
print("Total number of Rows in dataset " + str(wineData.shape[0]))
print("Total number of Columns in dataset " + str(wineData.shape[1]))
# Out:
# Total number of Rows in dataset 1599
# Total number of Columns in dataset 12

# %%
# Display top 5 rows of the dataset. 
wineData.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Display bottom 5 rows of the dataset. 
wineData.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
# Printing columns name of the given dataset
wineData.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
wineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Sure, here's the key information from the dataset analysis presented in bullet points:
#
# -The dataset contains a total of 1599 entries (rows) and 12 columns.
#
# -The variables in the dataset primarily have integer64 and float64 data types.
#
# -Among the columns, only the 'Quality' column retains the int64 data type, while the others are float64.
#
# -The second column of the dataset provides information about the size of the dataset and the count of non-null
#  values for each field.
#
# -The total memory usage of the dataset is approximately 150 kilobytes.

# %%
wineData.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# The dataset comprises variables primarily stored as float64 data types, with the exception of the 'Quality' variable, which is stored as int64.

# %%
 # returns the total number of unique values for each variable.
wineData.nunique().to_frame("Unique Values in each column")
# Out:
#                       Unique Values in each column
# fixed acidity                                   96
# volatile acidity                               143
# citric acid                                     80
# residual sugar                                  91
# chlorides                                      153
# free sulfur dioxide                             60
# total sulfur dioxide                           144
# density                                        436
# pH                                              89
# sulphates                                       96
# alcohol                                         65
# quality                                          6

# %% [markdown]
# This dataset includes categorical data, with 'Quality' serving as the target variable, containing categorical information.

# %%
#checking the value count for each columns

for col in wineData.columns:   
    print('--' * 10 + col + '--' * 10 )
    display(wineData[col].value_counts())
# Out:
# --------------------fixed acidity--------------------
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
# --------------------volatile acidity--------------------
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
# --------------------citric acid--------------------
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
# --------------------residual sugar--------------------
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# ...

# %% [markdown]
# The dataset displays the total count of unique values for each column and row.

# %%
#summarizes the count, mean, standard deviation, min, and max for numeric variables.
wineData.describe(include = 'all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# All columns exhibit a consistent count of 1599, indicating the absence of null values in the dataset.
#
# In each column, the mean exceeds the median (50th percentile), implying right-sided skewness in the data distribution.
#
# Significant gaps between the 75th percentile (quantile 3) and the maximum values are observed in 'residual sugar,' 'free sulfurdioxide,' and 'total sulfur dioxide,' suggesting the presence of skewness or outliers.
#
# The standard deviation values for 'free sulfurdioxide' and 'total sulfur dioxide' indicate substantial dispersion, suggesting a higher likelihood of outliers in these variables.

# %%
wineData.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %% [markdown]
# Description:
#
# This code computes the average value of each numeric column for different quality ratings of wine.
#
# By grouping the data based on the quality ratings, it allows for a comparison of the average characteristics of wines across different quality levels.
#
# The resulting DataFrame will have quality ratings as the index and the mean values of each numeric column as the data.

# %%
# Display the Missing Values
wineData.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Indicates that there are no null values within the dataset.

# %%
#graphical representaion of null values
sns.heatmap(wineData.isnull())
# Out:
# <Axes: >

# %%
sns.catplot(x='quality',data=wineData,kind = 'count')

# %% [markdown]
# From the catplot presented above, it's evident that the dataset contains a higher count of wines with quality ratings of 5 and 6.

# %%
plt.bar(wineData['quality'],wineData['fixed acidity'])
plt.xlabel('Quality')
plt.ylabel('Fixed acidity')
plt.show()

# %% [markdown]
# This bar plot demonstrates that there is a positive correlation between fixed acidity and the quality of wine: as fixed acidity increases, so does the quality rating of the wine.

# %%
plt.bar(wineData['quality'],wineData['volatile acidity'])
plt.xlabel('Quality')
plt.ylabel('Volatile acidity')
plt.show()

# %% [markdown]
# This bar plot illustrates a negative correlation between volatile acidity and the quality of wine: as volatile acidity increases, the quality of the wine decreases.

# %%
plt.bar(wineData['quality'],wineData['residual sugar'])
plt.xlabel('Quality')
plt.ylabel('Residual sugar')
plt.show()

# %% [markdown]
# When sugar levels are lower, the wine tends to have a more bitter taste, impacting its overall quality.

# %%
plt.bar(wineData['quality'],wineData['chlorides'])
plt.xlabel('Quality')
plt.ylabel('Chlorides')
plt.show()

# %% [markdown]
# The plot suggests that wines with lower chloride levels tend to have a more bitter taste, influencing their overall quality.

# %%
plt.bar(wineData['quality'],wineData['total sulfur dioxide'])
plt.xlabel('Quality')
plt.ylabel('Total sulfur dioxide')
plt.show()

# %% [markdown]
# Observing the data, it appears that there isn't a significant correlation between the total sulfur dioxide levels and the quality of the wine.

# %%
plt.bar(wineData['quality'],wineData['alcohol'])
plt.xlabel('Quality')
plt.ylabel('alcohol')
plt.show()

# %% [markdown]
# From our observation, it appears that there's a positive correlation between alcohol content and wine quality; as alcohol content increases, so does the quality of the wine.

# %%
wineData.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# Key Observations:
#
# Certain features, such as 'density' and 'pH', exhibit a roughly normal distribution.
#
# However, most independent variables, including 'Fixed acidity,' 'volatile acidity,' 'citric acid,' 'residual sugar,' 'chlorides,' 'free sulfur dioxide,' 'total sulfur dioxide,' 'sulphates,' and 'alcohol' columns, display varying degrees of skewness.
#
# Notably, there is pronounced skewness in 'residual sugar,' 'chlorides,' 'sulphates,' 'free sulfur dioxide,' and 'total sulfur dioxide' columns.

# %%
col = ['residual sugar','chlorides','sulphates','free sulfur dioxide','total sulfur dioxide']
for i in col:
    wineData[i] = np.log(wineData[i])

# %% [markdown]
# We are addressing the skewness in the notable columns by applying a log transformation to them.

# %%
wineData.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          1.806864
# chlorides               1.745215
# free sulfur dioxide    -0.234031
# total sulfur dioxide   -0.079323
# density                 0.071288
# pH                      0.193683
# sulphates               0.921867
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# Following the application of the log transformation, the skewness in the data has significantly improved.

# %%
wineData['quality'] = [0 if x <= 6 else 1 for x in wineData['quality']]

# %%
wineData
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00        0.641854  -2.577022
# 1               7.8             0.880         0.00        0.955511  -2.322788
# 2               7.8             0.760         0.04        0.832909  -2.385967
# 3              11.2             0.280         0.56        0.641854  -2.590267
# 4               7.4             0.700         0.00        0.641854  -2.577022
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08        0.693147  -2.407946
# 1595            5.9             0.550         0.10        0.788457  -2.780621
# 1596            6.3             0.510         0.13        0.832909  -2.577022
# 1597            5.9             0.645         0.12        0.693147  -2.590267
# 1598            6.0             0.310         0.47        1.280934  -2.703063
#
# ...

# %% [markdown]
# In this analysis, we're applying binarization to the 'quality' column. We're setting a threshold value of 6, where any quality rating less than 6 will be encoded as 0, and any rating equal to or greater than 6 will be encoded as 1.

# %% [markdown]
# Data Visualization

# %%
sns.catplot(x='quality',y='fixed acidity',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='volatile acidity',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='citric acid',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='residual sugar',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='chlorides',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='free sulfur dioxide',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='total sulfur dioxide',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='density',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='pH',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='sulphates',data=wineData)
plt.show()

# %%
sns.catplot(x='quality',y='alcohol',data=wineData)
plt.show()

# %% [markdown]
# Upon analyzing the graphs, it's evident that the relationship between the quality of each column follows a mostly normal distribution, albeit with a few outliers. We intend to remove these outliers for our subsequent analysis.

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
sns.barplot(x="quality", y="alcohol", data=wineData)
plt.title("The association between wine quality and alcohol content.")
# Out:
# Text(0.5, 1.0, 'The association between wine quality and alcohol content.')

# %%
plt.subplot(1,2,2)
sns.barplot(x="quality", y="volatile acidity", data=wineData)
plt.title("The association between Quality of wine and volatile acidity")
# Out:
# Text(0.5, 1.0, 'The association between Quality of wine and volatile acidity')

# %%
wineData.hist(bins=50,figsize=(15,15))
plt.show()

# %%
## using distplot
plt.figure(figsize=(20,20))
plotnumber=1
for column in wineData:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(wineData[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
# Detecting outliers using boxplot.

plt.figure(figsize=(20,20),facecolor='white')
num = 1

for col in wineData:
    if num <= 12:
        ax = plt.subplot(4,3,num)
        sns.boxplot(wineData[col])
        plt.xlabel(col,fontsize=16)
    num += 1
plt.show()

# %% [markdown]
# Key Observations:
#
# Outliers are noticeable across nearly all columns, with notable concentrations observed in 'Total sulfur dioxide,' 'Free sulfur dioxide,' 'residual sugar,' and 'chlorides.'
# Several features exhibit outliers at both extremes, indicating their widespread presence throughout the dataset.

# %%
wineData.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.174742          0.024278     0.172286
# chlorides                  0.175191          0.108726     0.181780
# free sulfur dioxide       -0.179211          0.016666    -0.089146
# total sulfur dioxide      -0.117900          0.073407    -0.003637
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.204294         -0.300549     0.331516
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.120061         -0.270712     0.214716
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(wineData.corr(),annot=True,fmt='0.2f', cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# The relationship between density and citric acid appears to be closely linked to fixed acidity. However, further analysis is required to delve deeper into this association.

# %%
plt.scatter(wineData['fixed acidity'], wineData['density'])
plt.xlabel('Fixed Acidity')
plt.ylabel('density')
plt.title('Fixed Acidity vs density')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(wineData['fixed acidity'], wineData['citric acid'])
plt.xlabel('Fixed Acidity')
plt.ylabel('citric acid')
plt.title('Fixed Acidity vs citric acid')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (22,10))
wineData.corr()['quality'].sort_values(ascending = False).drop(['quality']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize = 15)
plt.ylabel('Target',fontsize = 15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %% [markdown]
# In conclusion, the physiochemical properties most strongly correlated with wine quality are alcohol content, sulphates, fixed acidity, and citric acid. These factors emerge as the key determinants of a wine's overall quality.

# %%
wineData['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
#Removing Outliers
from scipy.stats import zscore
z=np.abs(zscore(wineData))
z
threshold=3
np.where(z>3)
# Out:
# (array([  13,   17,   17,   19,   33,   38,   42,   45,   81,   81,   83,
#           86,   91,   92,   95,  106,  106,  120,  126,  127,  142,  144,
#          147,  151,  151,  151,  151,  163,  164,  169,  169,  181,  199,
#          226,  226,  240,  243,  244,  258,  258,  274,  281,  291,  324,
#          325,  339,  347,  374,  381,  391,  396,  400,  442,  442,  451,
#          467,  480,  480,  494,  530,  535,  544,  554,  554,  555,  555,
#          557,  557,  566,  567,  568,  588,  595,  608,  614,  639,  649,
#          652,  652,  652,  666,  672,  690,  692,  695,  723,  724,  730,
#          754,  773,  776,  777,  821,  836,  836,  837,  837,  889,  911,
#          917,  923, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1081,
#         1111, 1114, 1165, 1186, 1235, 1244, 1260, 1269, 1269, 1270, 1270,
#         1299, 1300, 1312, 1316, 1319, 1319, 1321, 1370, 1372, 1374, 1434,
#         1434, 1435, 1435, 1474, 1474, 1476, 1476, 1558, 1570, 1574, 1589]),
# ...

# %%
df=wineData[(z<3).all(axis=1)]
df.shape
# Out:
# (1482, 12)

# %%
df['quality'].value_counts()
# Out:
# 0    1279
# 1     203
# Name: quality, dtype: int64

# %% [markdown]
# Filtering out the outliers from the dataset.

# %%
sns.countplot(x ='quality', data = wineData)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
print("Data Loss Percentage :",((wineData.shape[0]-df.shape[0])/wineData.shape[0])*100)
# Out:
# Data Loss Percentage : 7.317073170731707

# %% [markdown]
# The data loss should be minimized to ensure it remains below 10%.

# %%
x=df.drop('quality',axis=1)
y=df['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00        0.641854  -2.577022
# 1               7.8             0.880         0.00        0.955511  -2.322788
# 2               7.8             0.760         0.04        0.832909  -2.385967
# 3              11.2             0.280         0.56        0.641854  -2.590267
# 4               7.4             0.700         0.00        0.641854  -2.577022
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08        0.693147  -2.407946
# 1595            5.9             0.550         0.10        0.788457  -2.780621
# 1596            6.3             0.510         0.13        0.832909  -2.577022
# 1597            5.9             0.645         0.12        0.693147  -2.590267
# 1598            6.0             0.310         0.47        1.280934  -2.703063
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1482, dtype: int64

# %%
# Balancing the dataset using the SMOTE
import imblearn
from imblearn.over_sampling import SMOTE
x_smote,y_smote = SMOTE().fit_resample(x,y)
y_smote.value_counts()
# Out:
# 0    1279
# 1    1279
# Name: quality, dtype: int64

# %% [markdown]
# Following the application of SMOTE, the count of both class values has been equalized, indicating a balanced dataset suitable for model creation.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
max_Acc = 0
max_RS = 0

for i in range (1,200):
    x_train, x_test, y_train, y_test = train_test_split(x_smote, y_smote, test_size = 0.20, random_state=i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    predlr = lr.predict(x_test)
    acc = accuracy_score(y_test, predlr)
    if acc>max_Acc:
        max_Acc = acc
        max_RS = i
print("LogisticRegression model")        
print ('Best Accuracy is ', max_Acc, " on Random_State ", max_RS)
# Out:
# LogisticRegression model
# Best Accuracy is  0.869140625  on Random_State  114

# %%
#Now splitting the dataset into the Training set and test set
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.20,random_state=46)

# %%
print('Size of X_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of X_test : ', x_test.shape)
print('Size of Y_test : ', y_test.shape)
# Out:
# Size of X_train :  (2046, 11)
# Size of y_train :  (2046,)
# Size of X_test :  (512, 11)
# Size of Y_test :  (512,)

# %% [markdown]
# # Feature Scaling

# %%
#feature scaling
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test =st.transform(x_test)

# %% [markdown]
# Feature scaling has been performed using the standard scaler to mitigate bias-related issues in the data.

# %%
#Using PCA (Principal component analysis)for dimensionality reduction
pca=PCA(n_components=0.90)
x_train=pca.fit_transform(x_train)
x_test =pca.transform(x_test)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9374882459145445

# %% [markdown]
# # Logistic Regression

# %%
# Now applying Logistic regression
log= LogisticRegression()
log.fit(x_train,y_train)
logPred=log.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,logPred,output_dict=True))

print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,logPred)}\n")
print("Accuracy score",accuracy_score(y_test,logPred))
score = cross_val_score(log,x,y,cv=5)
print("Cross val score: ", score.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.794677    0.831325    0.8125    0.813001      0.813359
# recall       0.832669    0.793103    0.8125    0.812886      0.812500
# f1-score     0.813230    0.811765    0.8125    0.812497      0.812483
# support    251.000000  261.000000    0.8125  512.000000    512.000000
#
#  Confusion Matrix:
# [[209  42]
#  [ 54 207]]
#
# Accuracy score 0.8125
# Cross val score:  0.8765333515333514

# %% [markdown]
# # Support Vector Classifier

# %%
svm = SVC()
svm.fit(x_train,y_train)
svmPred = svm.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,svmPred,output_dict=True))

print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,svmPred)}\n")
print("Accuracy score",accuracy_score(y_test,svmPred))
score1 = cross_val_score(svm,x,y)
print("Cross val score:",score1.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.876543    0.858736  0.867188    0.867640      0.867466
# recall       0.848606    0.885057  0.867188    0.866832      0.867188
# f1-score     0.862348    0.871698  0.867188    0.867023      0.867114
# support    251.000000  261.000000  0.867188  512.000000    512.000000
#
#  Confusion Matrix:
# [[213  38]
#  [ 30 231]]
#
# Accuracy score 0.8671875
# Cross val score: 0.8630243880243882

# %% [markdown]
# # DecisionTreeClassifier

# %%
dt =DecisionTreeClassifier()
dt.fit(x_train,y_train)
dtPred= dt.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,dtPred,output_dict=True))

print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,dtPred)}\n")
print("Accuracy score",accuracy_score(y_test,dtPred))
score2 = cross_val_score(dt,x,y)
print("Cross val score: ", score2.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.882591    0.875472  0.878906    0.879031      0.878962
# recall       0.868526    0.888889  0.878906    0.878707      0.878906
# f1-score     0.875502    0.882129  0.878906    0.878816      0.878880
# support    251.000000  261.000000  0.878906  512.000000    512.000000
#
#  Confusion Matrix:
# [[218  33]
#  [ 29 232]]
#
# Accuracy score 0.87890625
# Cross val score:  0.8272499772499773

# %% [markdown]
# # RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
rfPred = rf.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,rfPred,output_dict=True))

print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,rfPred)}\n")
print("Accuracy score",accuracy_score(y_test,rfPred))
score3 = cross_val_score(rf,x,y)
print("Cross val score: ", score3.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.951417    0.939623  0.945312    0.945520      0.945405
# recall       0.936255    0.954023  0.945312    0.945139      0.945312
# f1-score     0.943775    0.946768  0.945312    0.945272      0.945301
# support    251.000000  261.000000  0.945312  512.000000    512.000000
#
#  Confusion Matrix:
# [[235  16]
#  [ 12 249]]
#
# Accuracy score 0.9453125
# Cross val score:  0.8785399035399035

# %% [markdown]
# # GradientBoostingClassifier

# %%
gbc= GradientBoostingClassifier()
gbc.fit(x_train,y_train)
gbcPred=gbc.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,gbcPred,output_dict=True))

print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,gbcPred)}\n")
print("Accuracy score:",accuracy_score(y_test,gbcPred))
score4 = cross_val_score(gbc,x,y)
print("Cross val score: ", score4.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.902834    0.894340  0.898438    0.898587      0.898504
# recall       0.888446    0.908046  0.898438    0.898246      0.898438
# f1-score     0.895582    0.901141  0.898438    0.898362      0.898416
# support    251.000000  261.000000  0.898438  512.000000    512.000000
#
#  Confusion Matrix:
# [[223  28]
#  [ 24 237]]
#
# Accuracy score: 0.8984375
# Cross val score:  0.8637068887068887

# %% [markdown]
# # KNeighborsClassifier

# %%
knn =KNeighborsClassifier()
knn.fit(x_train,y_train)
knnPred = knn.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,knnPred,output_dict=True))

print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,knnPred)}\n")
print("Accuracy score",accuracy_score(y_test,knnPred))
score5 = cross_val_score(knn,x,y)
print("Cross val score: ", score5.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.980769    0.845395  0.900391    0.913082      0.911760
# recall       0.812749    0.984674  0.900391    0.898712      0.900391
# f1-score     0.888889    0.909735  0.900391    0.899312      0.899515
# support    251.000000  261.000000  0.900391  512.000000    512.000000
#
#  Confusion Matrix:
# [[204  47]
#  [  4 257]]
#
# Accuracy score 0.900390625
# Cross val score:  0.867073892073892

# %%
final_data = pd.DataFrame({'Model':['LR','SVC','DT','RF','GBC','KNN'],
                    'Accuracy_score':[accuracy_score(y_test,logPred)*100,
                           accuracy_score(y_test,svmPred)*100,
                          accuracy_score(y_test,dtPred)*100,
                          accuracy_score(y_test,rfPred)*100,
                          accuracy_score(y_test,gbcPred)*100,
                          accuracy_score(y_test,knnPred)*100],
                    'Cross_val_score':[score.mean()*100,score1.mean()*100,score2.mean()*100,score3.mean()*100,score4.mean()*100,
                                      score5.mean()*100]})
final_data['Score_diff'] = final_data['Accuracy_score'] - final_data['Cross_val_score']

# %%
final_data
# Out:
#   Model  Accuracy_score  Cross_val_score  Score_diff
# 0    LR       81.250000        87.653335   -6.403335
# 1   SVC       86.718750        86.302439    0.416311
# 2    DT       87.890625        82.724998    5.165627
# 3    RF       94.531250        87.853990    6.677260
# 4   GBC       89.843750        86.370689    3.473061
# 5   KNN       90.039062        86.707389    3.331673

# %% [markdown]
# The RandomForestClassifier is yielding the highest accuracy rate at 94.5%.

# %% [markdown]
# Through the utilization of cross-validation scores, we've addressed the challenges of overfitting and underfitting. Notably, the SVC model exhibits the smallest disparity between accuracy and cross-validation scores, indicating its robust performance.

# %% [markdown]
# we should plot the ROC-AUC curve to check the best fit model

# %%
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import roc_curve

# %%
# Compute ROC curves for each model
fpr_dt, tpr_dt, _ = roc_curve(y_train, dt.predict_proba(x_train)[:, 1])
fpr_log, tpr_log, _ = roc_curve(y_train, log.predict_proba(x_train)[:, 1])
fpr_svm, tpr_svm, _ = roc_curve(y_train, svm.decision_function(x_train))
fpr_rf, tpr_rf, _ = roc_curve(y_train, rf.predict_proba(x_train)[:, 1])
fpr_knn, tpr_knn, _ = roc_curve(y_train, knn.predict_proba(x_train)[:, 1])
fpr_gbc, tpr_gbc, _ = roc_curve(y_train, gbc.predict_proba(x_train)[:, 1])

# Plot ROC curves
plt.figure(figsize=(6, 4))
plt.plot(fpr_dt, tpr_dt, label='Decision Tree')
plt.plot(fpr_log, tpr_log, label='Logistic Regression')
plt.plot(fpr_svm, tpr_svm, label='SVM')
plt.plot(fpr_rf, tpr_rf, label='Random Forest')
plt.plot(fpr_knn, tpr_knn, label='KNN')
plt.plot(fpr_gbc, tpr_gbc, label='Gradient Boosting')

# Add labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Different Models')
plt.legend(prop={'size': 10}, loc='lower right')

# Show plot
plt.show()

# %%
# Compute ROC curves for each model
fpr_dt, tpr_dt, _ = roc_curve(y_test, dt.predict_proba(x_test)[:, 1])
fpr_log, tpr_log, _ = roc_curve(y_test, log.predict_proba(x_test)[:, 1])
fpr_svm, tpr_svm, _ = roc_curve(y_test, svm.decision_function(x_test))
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf.predict_proba(x_test)[:, 1])
fpr_knn, tpr_knn, _ = roc_curve(y_test, knn.predict_proba(x_test)[:, 1])
fpr_gbc, tpr_gbc, _ = roc_curve(y_test, gbc.predict_proba(x_test)[:, 1])

# Plot ROC curves
plt.figure(figsize=(6, 4))
plt.plot(fpr_dt, tpr_dt, label='Decision Tree')
plt.plot(fpr_log, tpr_log, label='Logistic Regression')
plt.plot(fpr_svm, tpr_svm, label='SVM')
plt.plot(fpr_rf, tpr_rf, label='Random Forest')
plt.plot(fpr_knn, tpr_knn, label='KNN')
plt.plot(fpr_gbc, tpr_gbc, label='Gradient Boosting')

# Add labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Different Models')
plt.legend(prop={'size': 10}, loc='lower right')

# Show plot
plt.show()

# %% [markdown]
# Based on the analysis of the ROC curves:
#
# The models exhibit significant overfitting, as indicated by the disparity between training and cross-validation scores.
#
# Despite its lower testing accuracy, Logistic Regression demonstrates no overfitting concerns.
#
# Logistic Regression emerges as the preferred model due to its testing data's commendable AUC value of 0.92.
#
# However, Gradient Boosting and Random Forest could be viable alternatives if prioritizing accuracy over the overfitting challenge.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
 
# Creating the hyperparameter grid
param_grid = {'solver': ['newton-cg', 'lbfgs', 'liblinear','saga','sag'],
              'penalty': ['l1','l2'],
              'C':[0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
             'dual':[True,False],
            'max_iter': [100,110,120,130,140]}

# Instantiating logistic regression classifier
model = LogisticRegression()
# Instantiating the GridSearchCV object
gsv = GridSearchCV( estimator = model,  param_grid = param_grid, cv = 5)
gsv.fit(x_train, y_train)
 
# Print the tuned parameters and score
print("Tuned Logistic Regression Parameters: {}".format(gsv.best_params_))
print("Best score is {}".format(gsv.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'C': 10, 'dual': True, 'max_iter': 130, 'penalty': 'l2', 'solver': 'liblinear'}
# Best score is 0.8088818653467709

# %%
model = LogisticRegression(solver = 'liblinear', C = 10, penalty = 'l2',dual=True,max_iter=130)

# %%
model.fit(x_train,y_train)
pred = model.predict(x_test)
print("Accuracy score",accuracy_score(y_test,pred)*100)
print("Confusion Matrix",confusion_matrix(y_test,pred))
print("Classification Report",classification_report(y_test,pred))
# Out:
# Accuracy score 81.25
# Confusion Matrix [[209  42]
#  [ 54 207]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       251
#            1       0.83      0.79      0.81       261
#
#     accuracy                           0.81       512
#    macro avg       0.81      0.81      0.81       512
# weighted avg       0.81      0.81      0.81       512
