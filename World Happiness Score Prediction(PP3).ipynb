# %%
#importing the required python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#importing the dataset
report = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
report
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Displaying the top 5 rows of datasets
report.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Display the bottom 5 rows of the dataset. 
report.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
#display the Count of number of rows and column
print('Column, Rows:',report.shape)
# Out:
# Column, Rows: (158, 12)

# %%
#Display the info about the dataset
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Country, Region have (object dtype) ;
#
# Happiness Rank have (integer 64 datatype)
#
# rest all other have (float64 datatype)
#
# No Null values present in the dataset and The overall memory consumption for this dataset amounts to approximately 14.9 KB.

# %%
# Seperating categorical columns and numerical columns from the datasets
categorical_data = []
numerical_data = []

for i in report.columns:
    if report[i].dtype=='object':
        categorical_data.append(i)
    else:
        numerical_data.append(i)
        

print("The Categorical Data is present in columns: \n",*categorical_data,sep='\n')
print("\n The Numerical Data is present in columns: \n",*numerical_data,sep='\n')
# Out:
# The Categorical Data is present in columns:
#
# Country
# Region
#
#  The Numerical Data is present in columns:
#
# Happiness Rank
# Happiness Score
# Standard Error
# Economy (GDP per Capita)
# Family
# Health (Life Expectancy)
# Freedom
# Trust (Government Corruption)
# Generosity
# Dystopia Residual

# %%
#Checking Null values
report.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#graphical representaion of null values
sns.heatmap(report.isnull())
# Out:
# <Axes: >

# %% [markdown]
#  no null values present in the Dataset

# %%
# Count of total number of unique values in each variable.

report.nunique().to_frame("Total No. of Unique Values in each column")
# Out:
#                                Total No. of Unique Values in each column
# Country                                                              158
# Region                                                                10
# Happiness Rank                                                       157
# Happiness Score                                                      157
# Standard Error                                                       153
# Economy (GDP per Capita)                                             158
# Family                                                               158
# Health (Life Expectancy)                                             157
# Freedom                                                              158
# Trust (Government Corruption)                                        157
# Generosity                                                           158
# Dystopia Residual                                                    158

# %%
#Performing the operation for identify the count of unique values in each columns

for col in report.columns:   
    print('--' * 10 + col + '--' * 10)
    display(report[col].value_counts())
# Out:
# --------------------Country--------------------
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
# --------------------Region--------------------
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
# --------------------Happiness Rank--------------------
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# ...

# %%
#Displaying values of rows and columns
report.shape
# Out:
# (158, 12)

# %%
#Droping Duplicate Values if any
report.drop_duplicates(inplace=True)
report.shape
# Out:
# (158, 12)

# %% [markdown]
# There are no repeated values present.

# %%
report.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Key observation findings:
#
# The dataset contains 158 unique rows and 12 columns, with no null values present.
#
# there is no Significant standard deviations are observed in the data.
#
# there is no skewness are present in datastes.
# there no major noticable data in the datastes

# %%
# Top 10 countries with Highest Happiness Score
sort_report= report.sort_values(by='Happiness Score', ascending=False)
sort_report.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
#Bottom 10 Countries with least Happiness score
sort_report.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %% [markdown]
# # Data Visualization

# %%
cols = ['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
for i in cols:
    sns.lmplot(x='Happiness Score',y=i,data=report)

# %% [markdown]
# Key Observations:
#
# Outliers are quite noticeable, with notable concentrations observed.

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)',hue='Region',s=20,data= report)
gdp_region=report.groupby('Region')['Economy (GDP per Capita)'].sum()
gdp_region
# Out:
# Region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy (GDP per Capita), dtype: float64

# %% [markdown]
# A key observation from the plot reveals that the Economy (GDP per Capita) data shows high values across multiple columns, including 'Central and Eastern Europe', 'Latin America and Caribbean', 'Middle East and Northern Africa', 'Sub-Saharan Africa', and 'Western Europe'.

# %%
sns.barplot(x='Happiness Score',y='Region',data= report, palette='Dark2')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Region'>

# %% [markdown]
# Based on the bar plot, it is evident that the highest happiness scores based on region are observed in 'North America' and 'Australia and New Zealand'.

# %%
plt.figure(figsize = (10,10))
#plotting with only one decimal place
report['Region'].value_counts().plot(kind='pie',autopct='%1.1f%%');
report['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
#TOTAL COUNTRY COUNT IN A REGION
total_country=report.groupby('Region')[['Country']].count()
total_country
# Out:
#                                  Country
# Region
# Australia and New Zealand              2
# Central and Eastern Europe            29
# Eastern Asia                           6
# Latin America and Caribbean           22
# Middle East and Northern Africa       20
# North America                          2
# Southeastern Asia                      9
# Southern Asia                          7
# Sub-Saharan Africa                    40
# Western Europe                        21

# %%
#corruption in region
corruption=report.groupby('Region')[['Trust (Government Corruption)']].mean()
corruption
sns.barplot(x='Region',y='Trust (Government Corruption)',data=report)
plt.xticks(rotation=40,ha='right')
plt.title('Corruption in regions')
# Out:
# Text(0.5, 1.0, 'Corruption in regions')

# %% [markdown]
# Based on the bar plot, it is apparent that the region with the highest level of corruption is Australia and New Zealand.

# %%
#Life Expectancy in region
sns.barplot(x='Region',y='Health (Life Expectancy)',data=report)
plt.xticks(rotation=40,ha='right')
plt.title('Life Expectancy in regions')
# Out:
# Text(0.5, 1.0, 'Life Expectancy in regions')

# %%
#Economy in region
sns.barplot(x='Region',y='Economy (GDP per Capita)',data=report)
plt.xticks(rotation=40,ha='right')
plt.title('Economy in regions')
# Out:
# Text(0.5, 1.0, 'Economy in regions')

# %%
#probability of happiness score
plt.figure(figsize = (8,8))
report['Happiness Score'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber=1
for column in numerical_data:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.histplot(report[column])
        plt.xlabel(column, fontsize=15)
    plotnumber+=1
plt.show()

# %%
#swarmplot: draw a categorical scatterplot with non-overlapping points
for i in col_plot:
    plt.figure(figsize = (15,8))
    sns.stripplot(x = "Region", y = i, data = report)
    plt.xticks(rotation = 60)
    plt.title("Distribution by Region")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #swarmplot: draw a categorical scatterplot with non-overlapping points
# ----> 2 for i in col_plot:
#       3     plt.figure(figsize = (15,8))
#       4     sns.stripplot(x = "Region", y = i, data = report)
#
# NameError: name 'col_plot' is not defined

# %%
# using distplot
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1
for column in numerical_data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(report[column], color = 'r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Skewness is noticeable in the dataset, indicating an asymmetrical distribution of values either to the right or left.

# %%
report.plot(kind='box', subplots=True, layout=(2,5), legend=True, figsize=(20,8))
plt.show()

# %% [markdown]
# Key Observations:
#
# Outliers are quite noticeable, with notable concentrations observed in 'Standard error,' 'Family,' 'trust,'

# %%
plt.figure(figsize = (15,10), facecolor='pink')
plotnumber = 1

for column in numerical_data:
    if plotnumber<=8 :
        ax = plt.subplot(2,4,plotnumber)
        plt.scatter(report[column],report['Happiness Score'])
        plt.xlabel(column,fontsize=10)
        plt.ylabel('charges',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# Check the relationship among the columns
sns.pairplot(report)

# %%
report.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(20,14))
sns.heatmap(report.corr(), annot=True, fmt='0.2f', linewidths=0.30, cmap="pink")
# Out:
# <Axes: >

# %%
report.corr()['Happiness Score'].sort_values(ascending = False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize = (22,10))
report.corr()['Happiness Score'].sort_values(ascending = False).drop(['Happiness Score']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize = 15)
plt.ylabel('Target',fontsize = 15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %% [markdown]
# Happiness rank is very negetively correlated with happiness score.
#
# Economy(GDP per Capita), Family and Health (Life expectency), Freedom, Trust, Residual shows positive correlation with Happiness score

# %% [markdown]
# # Checking Skewness

# %%
report.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Removing Skewness

# %%
from scipy.stats import boxcox

# %%
report['Standard Error']=boxcox(report['Standard Error'],0)

# %%
report.skew() # remove the skewness from 'standard error' column
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# #skewness  is present in dataset

# %%
col = ['Trust (Government Corruption)','Generosity']
for i in col:
    report[i] = np.cbrt(report[i]) # remove the skewness from 'Trust (Government Corruption)','Generosity' column

# %%
report.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# After addressing the skewness, the dataset is now free from skewness.

# %%
report=report.drop(['Country'],axis=1)  #droping the column from dataset due to no use of that column in analysis

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    object
#  1   Happiness Rank                 158 non-null    int64
#  2   Happiness Score                158 non-null    float64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 13.7+ KB

# %%
report.nunique()
# Out:
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
report['Region'] = label.fit_transform(report['Region'])

# %%
report['Region']
# Out:
# 0      9
# 1      9
# 2      9
# 3      9
# 4      5
#       ..
# 153    8
# 154    8
# 155    4
# 156    8
# 157    8
# Name: Region, Length: 158, dtype: int64

# %% [markdown]
# Apply label encoding to convert categorical data into numerical format.

# %% [markdown]
# # checking for Ouliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(report))
threshold=3
print(np.where(z>3))
# Out:
# (array([ 63,  64,  73, 101, 147, 155, 157]), array([ 9,  3,  8,  9,  5, 10,  5]))

# %%
df=report[(z<3).all(axis=1)]
df
# Out:
#      Region  Happiness Rank  Happiness Score  Standard Error  \
# 0         9               1            7.587       -3.378165
# 1         9               2            7.561       -3.019206
# 2         9               3            7.527       -3.402799
# 3         9               4            7.522       -3.249335
# 4         5               5            7.427       -3.337378
# ..      ...             ...              ...             ...
# 151       8             152            3.587       -3.140989
# 152       7             153            3.575       -3.478943
# 153       8             154            3.465       -3.362746
# 154       8             155            3.340       -3.308801
# 156       8             157            2.905       -2.446686
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# ...

# %%
print("Data Loss Percentage :",((report.shape[0]-df.shape[0])/report.shape[0])*100)
# Out:
# Data Loss Percentage : 4.430379746835443

# %% [markdown]
# # Splitting the Dataset

# %%
x = df.drop(['Happiness Score'], axis=1)
y=df['Happiness Score']

# %%
x
# Out:
#      Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0         9               1       -3.378165                   1.39651
# 1         9               2       -3.019206                   1.30232
# 2         9               3       -3.402799                   1.32548
# 3         9               4       -3.249335                   1.45900
# 4         5               5       -3.337378                   1.32629
# ..      ...             ...             ...                       ...
# 151       8             152       -3.140989                   0.25812
# 152       7             153       -3.478943                   0.31982
# 153       8             154       -3.362746                   0.22208
# 154       8             155       -3.308801                   0.28665
# 156       8             157       -2.446686                   0.01530
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 151    3.587
# 152    3.575
# 153    3.465
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 151, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model  import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor , AdaBoostRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection  import GridSearchCV

# %% [markdown]
# # Standard scaling

# %%
scaler =StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
x_scaled
# Out:
#        Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0    1.303819       -1.699730       -0.933001                  1.354873
# 1    1.303819       -1.677684        0.263194                  1.120057
# 2    1.303819       -1.655638       -1.015091                  1.177795
# 3    1.303819       -1.633592       -0.503689                  1.510661
# 4   -0.033204       -1.611546       -0.797083                  1.179815
# ..        ...             ...             ...                       ...
# 146  0.969563        1.629212       -0.142638                 -1.483135
# 147  0.635307        1.651258       -1.268834                 -1.329317
# 148  0.969563        1.673304       -0.881621                 -1.572983
# 149  0.969563        1.695350       -0.701852                 -1.412010
# 150  0.969563        1.739442        2.171057                 -2.088486
#
#        Family  Health (Life Expectancy)   Freedom  \
# 0    1.374784                  1.257208  1.566004
# ...

# %% [markdown]
# Feature scaling was performed using a standard scaler to mitigate bias issues within the data.

# %%
#Checking Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x_scaled.values,i) for i in range(len(x_scaled.columns))]
vif['Features'] = x.columns

vif
# Out:
#    VIF values                       Features
# 0    1.627256                         Region
# 1   84.212036                 Happiness Rank
# 2    1.244812                 Standard Error
# 3   14.612548       Economy (GDP per Capita)
# 4    6.173914                         Family
# 5    8.780001       Health (Life Expectancy)
# 6    3.543474                        Freedom
# 7    2.059923  Trust (Government Corruption)
# 8    2.172995                     Generosity
# 9   19.436378              Dystopia Residual

# %% [markdown]
# VIF checks for multicollinearity in regression. High VIF means strong correlation between predictors, impacting result reliability. Low VIF improves model accuracy by identifying and addressing problematic variables.
#
# Very high VIF found in Happiness Rank column

# %%
x_scaled = x_scaled.drop(['Happiness Rank'], axis=1)
x= x_scaled   #so droping the 'Happiness Rank' column

# %%
#Checking Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#    VIF values                       Features
# 0    1.536682                         Region
# 1    1.226174                 Standard Error
# 2    4.049948       Economy (GDP per Capita)
# 3    1.951608                         Family
# 4    4.001766       Health (Life Expectancy)
# 5    1.940528                        Freedom
# 6    1.450612  Trust (Government Corruption)
# 7    1.446043                     Generosity
# 8    1.034068              Dystopia Residual

# %%
Model= [LinearRegression(),RandomForestRegressor(),KNeighborsRegressor(),DecisionTreeRegressor(), SVR(),GradientBoostingRegressor(),AdaBoostRegressor()]

# %%
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .30, random_state=i)
    for m in Model:
        maxScore = 0
        maxRs = 0
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        score = r2_score(y_test,pred)
        if score>maxScore:
            maxScore = score
            maxRs=i
print("Best Accuracy is:", maxScore, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.8651474847795675 on Random State: 49

# %%
#Now splitting the dataset into the Training set and test set
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=49)

# %%
print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (105, 9)
# Training target vector size: (105,)
# Test feature matrix size: (46, 9)
# Test target vector size: (46,)

# %%
from sklearn.model_selection import cross_val_score
for m in Model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print('--------------------',m,'-----------------------')
    print(f" R2 score is: {r2_score(y_test,predm)*100:.2f}")
    print ('\n','mean_absolute_error:','\n',mean_absolute_error(y_test,predm))
    print ('\n','mean_squared_error:','\n',mean_squared_error(y_test,predm))
    print ('\n','Root Mean Squared Error:','\n',np.sqrt(mean_squared_error(y_test,predm)))
    score = cross_val_score(m,x,y,cv=5,scoring='r2')
    print(f'\n Difference between R2 score and cross val score {(r2_score(y_test,predm)-score.mean())}')
    print('\n')
# Out:
# -------------------- LinearRegression() -----------------------
#  R2 score is: 99.84
#
#  mean_absolute_error:
#  0.03141131672577164
#
#  mean_squared_error:
#  0.0019511098527357378
#
#  Root Mean Squared Error:
#  0.044171369151699814
#
#  Difference between R2 score and cross val score 0.048689866425580375
#
#
# -------------------- RandomForestRegressor() -----------------------
#  R2 score is: 89.45
#
#  mean_absolute_error:
#  0.28789195652174
#
#  mean_squared_error:
#  0.1288719626543485
#
#  Root Mean Squared Error:
#  0.35898741294695624
#
#  Difference between R2 score and cross val score 4.654573414573305
#
#
# -------------------- KNeighborsRegressor() -----------------------
#  R2 score is: 85.96
#
#  mean_absolute_error:
#  0.33588695652173906
#
#  mean_squared_error:
#  0.17149071130434781
#
#  Root Mean Squared Error:
#  0.41411436983561417
#
#  Difference between R2 score and cross val score 6.43620611288424
#
#
# ...

# %% [markdown]
# The LinearRegression is yielding the highest accuracy rate at 99.84%.
#
# Through the utilization of cross-validation scores, we've addressed the challenges of overfitting and underfitting. Notably, the LinearRegression model exhibits the smallest disparity between accuracy and cross-validation scores, indicating its robust performance.
#
# we should plot the ROC-AUC curve to check the best fit model

# %% [markdown]
# # HyperParameter Tuning

# %%
lr=LinearRegression()
param={'fit_intercept':[True, False],
      'n_jobs':(10,20,50),
      'copy_X':[True,False],
      'positive':[True,False]}
gsv=GridSearchCV(lr,param,cv=5)
gsv.fit(x_train,y_train)
gsv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 10, 'positive': True}

# %%
model = LinearRegression(fit_intercept= True, copy_X= True, n_jobs= 10, positive= True)

# %%
model.fit(x_train,y_train)
pred = model.predict(x_test)
print('R2 score: ',r2_score(y_test,pred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred))
print('Mean Squared Error: ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score:  0.9984375888174214
# Mean Absolute Error:  0.031096926157583277
# Mean Squared Error:  0.0019081427045598278
# Root Mean Squared Error:  0.04368229280337546

# %%
pred_report=pd.DataFrame({'predicted values':pred,'actual values':y_test})
pred_report.head(10)
# Out:
#      predicted values  actual values
# 114          4.621568          4.610
# 146          3.703013          3.681
# 53           5.870613          5.855
# 83           5.075809          5.140
# 79           5.200128          5.212
# 86           5.119880          5.123
# 143          3.858091          3.845
# 131          4.310992          4.271
# 90           4.931791          5.057
# 91           4.966046          5.013

# %%
#Saving the model
import joblib 
joblib.dump(model,'happiness_score.pkl')
# Out:
# ['happiness_score.pkl']
