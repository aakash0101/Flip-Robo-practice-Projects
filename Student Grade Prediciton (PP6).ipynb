# %%
#Importing required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the Dataset
grade = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
grade
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
# Display total no. of rows and columns
print("Total number of Rows in dataset " + str(grade.shape[0]))
print("Total number of Columns in dataset " + str(grade.shape[1]))
# Out:
# Total number of Rows in dataset 571
# Total number of Columns in dataset 43

# %%
#Display the top 5 rows and columns of datasets
grade.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
#Display the bottom 5 rows and columns of datasets
grade.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
#Display Information about dataset
grade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# All the columns in the dataset are object datatype,thereby this means all features are categorical in nature.
# Only our target variable 'CGPA' is in float64 datatype.

# %%
#Display the shape of dataset
grade.shape
# Out:
# (571, 43)

# %%
#List the column names present in the dataset
grade.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
#Checking the null values in our dataset.
null_values = grade.isnull().sum()
null_values
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# null values are present in the dataset

# %%
# Total number of null Values present
null_values.sum()
# Out:
# 425

# %%
# Display the ratio of null values present in each column
null_col = grade.isnull().sum()/len(grade)*100
null_col = null_col.drop(null_col[null_col == 0].index)
null_col
# Out:
# CY-105        0.175131
# HS-105/12     0.175131
# MT-111        0.350263
# CS-106        0.350263
# EL-102        0.350263
# EE-119        0.350263
# ME-107        0.350263
# CS-107        0.350263
# HS-205/20     0.875657
# MT-222        0.875657
# EE-222        1.225919
# MT-224        1.225919
# CS-210        1.225919
# CS-211        0.875657
# CS-203        0.875657
# CS-214        1.050788
# EE-217        1.050788
# CS-212        1.050788
# CS-215        1.050788
# MT-331        1.576182
# EF-303        1.751313
# HS-304        1.751313
# CS-301        1.751313
# CS-302        1.751313
# TC-383        1.751313
# MT-442        1.751313
# EL-332        1.576182
# CS-318        1.576182
# CS-306        1.576182
# CS-312        1.751313
# CS-317        2.101576
# CS-403        2.101576
# CS-421        2.101576
# CS-406       14.886165
# CS-414        2.276708
# CS-419        2.276708
# CS-423        2.451839
# CS-412       13.835377
# dtype: float64

# %%
#Handling Missing Values - Simple Imputer Method
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
simple_impute= SimpleImputer(strategy = 'most_frequent')

# %%
col_transform =  make_column_transformer((simple_impute,['CY-105', 'HS-105/12', 'MT-111','CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214','EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312','CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412']),remainder='passthrough')

# %%
newgrade = pd.DataFrame(col_transform.fit_transform(grade),columns=['CY-105', 'HS-105/12', 'MT-111',
        'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412','Seat No.', 'PH-121', 'HS-101','CS-105', 'CGPA'])
newgrade
# Out:
#     CY-105 HS-105/12 MT-111 CS-106 EL-102 EE-119 ME-107 CS-107 HS-205/20  \
# 0       C-         C     C-      D     C-     B-     C-     C-        B+
# 1       D+         D     B-      D      A     D+      D     B+        C+
# 2        A        B-     B+     B-     B+     A-     A-     B-        A-
# 3       D+         D      D     D+     C-      D     C+      D         B
# 4       A-        B+      A     A-     B+      A     A-      C         A
# ..     ...       ...    ...    ...    ...    ...    ...    ...       ...
# 566      A        A-     A+     A-     A-     A+     B+     A+         A
# 567      A         A      A      A     A-      A      A     A+        B+
# 568     A-        B+      A      A      A      A      B     A+        B-
# 569      D         A      D     B-     C-     B-     C-     A+        C+
# 570      D         C      C      B     C+      C     D+     B-        C+
#
#     MT-222  ... CS-406 CS-414 CS-419 CS-423 CS-412  Seat No. PH-121 HS-101  \
# ...

# %%
# Rechecking if null values are present
newgrade.isna().sum()
# Out:
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# Seat No.     0
# PH-121       0
# HS-101       0
# CS-105       0
# CGPA         0
# dtype: int64

# %% [markdown]
# after computing , there is no null values present in dataset now

# %%
# checking for any duplicate values .
newgrade.duplicated().sum()
# Out:
# 0

# %%
# Dropping the column 'Seat No' 
newgrade = newgrade.drop(['Seat No.'],axis=1)
newgrade.head()
# Out:
#   CY-105 HS-105/12 MT-111 CS-106 EL-102 EE-119 ME-107 CS-107 HS-205/20 MT-222  \
# 0     C-         C     C-      D     C-     B-     C-     C-        B+      D
# 1     D+         D     B-      D      A     D+      D     B+        C+     B-
# 2      A        B-     B+     B-     B+     A-     A-     B-        A-      A
# 3     D+         D      D     D+     C-      D     C+      D         B     D+
# 4     A-        B+      A     A-     B+      A     A-      C         A      A
#
#    ... CS-421 CS-406 CS-414 CS-419 CS-423 CS-412 PH-121 HS-101 CS-105   CGPA
# 0  ...     C-     A-      A     C-      B     A-     B-     D+     D+  2.205
# 1  ...      D     A-     B-      C      C      B      A      D      C  2.008
# 2  ...      C      A      A      A     A-      A      A      B      A  3.608
# 3  ...     C-     B-      B     C+     C+     C+      D     C+     A-  1.906
# 4  ...     B-     A-      A     A-     A-      A     A-     A-      A  3.448
#
# [5 rows x 42 columns]

# %% [markdown]
# We excluded the seat number from the analysis because it was deemed unnecessary.

# %%
# Checking unique values in the dataset
newgrade.nunique()
# Out:
# CY-105        13
# HS-105/12     13
# MT-111        13
# CS-106        13
# EL-102        13
# EE-119        12
# ME-107        13
# CS-107        14
# HS-205/20     13
# MT-222        14
# EE-222        13
# MT-224        14
# CS-210        14
# CS-211        14
# CS-203        13
# CS-214        13
# EE-217        13
# CS-212        12
# CS-215        14
# MT-331        12
# EF-303        12
# HS-304        14
# CS-301        12
# CS-302        11
# TC-383        12
# MT-442        12
# EL-332        13
# CS-318        14
# CS-306        13
# CS-312        14
# CS-317        12
# CS-403        11
# CS-421        13
# CS-406        14
# CS-414        13
# CS-419        12
# CS-423        12
# CS-412        13
# Seat No.     571
# PH-121        13
# HS-101        12
# CS-105        11
# CGPA         491
# dtype: int64

# %%
# Getting statistical summary
newgrade.describe()
# Out:
#        CY-105 HS-105/12 MT-111 CS-106 EL-102 EE-119 ME-107 CS-107 HS-205/20  \
# count     571       571    571    571    571    571    571    571       571
# unique     13        13     13     13     13     12     13     14        13
# top         A         A     A-     A-     A-     A-     A-      A        A-
# freq      178        97    107    118    107    139     81    107       155
#
#        MT-222  ... CS-406 CS-414 CS-419 CS-423 CS-412  Seat No. PH-121 HS-101  \
# count     571  ...    571    571    571    571    571       571    571    571
# unique     14  ...     14     13     12     12     13       571     13     12
# top        A-  ...     A-      A     A-     A-     A-  CS-97001     A-     A-
# freq       91  ...    262    189    133    136    236         1    112     82
#
#        CS-105     CGPA
# count     571  571.000
# unique     11  491.000
# top         A    3.019
# freq      151    5.000
#
# [4 rows x 43 columns]

# %%
# Converting data type of CGPA into float
newgrade['CGPA'] = newgrade['CGPA'].astype(float)

# %%
newgrade.dtypes
# Out:
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# Seat No.      object
# PH-121        object
# HS-101        object
# CS-105        object
# CGPA         float64
# ...

# %%
# Applying Label encoder to categorical columns for analysis 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in newgrade.columns:
    if(newgrade[i].dtypes=='object'):
        newgrade[i]=le.fit_transform(newgrade[i].values.reshape(-1,1))

# %%
newgrade
# Out:
#      CY-105  HS-105/12  MT-111  CS-106  EL-102  EE-119  ME-107  CS-107  \
# 0         8          6       8       9       8       5       8       8
# 1        10          9       5       9       0      10       9       4
# 2         0          5       4       5       4       2       2       5
# 3        10          9       9      10       8       9       7       9
# 4         2          4       0       2       4       0       2       6
# ..      ...        ...     ...     ...     ...     ...     ...     ...
# 566       0          2       1       2       2       1       4       1
# 567       0          0       0       0       2       0       0       1
# 568       2          4       0       0       0       0       3       1
# 569       9          0       9       5       8       5       8       1
# 570       9          6       6       3       7       6      10       5
#
#      HS-205/20  MT-222  ...  CS-406  CS-414  CS-419  CS-423  CS-412  Seat No.  \
# ...

# %% [markdown]
# convert categorical data into numerical data

# %% [markdown]
# right skewness is present in CGPA column

# %% [markdown]
# # Data Visualisation

# %%
# Visualizing the dataset by using countplot

plt.figure(figsize=(25,100))
num = 1

for i in newgrade.columns[0:41]:
    if num <=41:
        st = plt.subplot(21,2,num)
        sns.countplot(data=newgrade,x=i)
        plt.xlabel(i,fontsize=15)
        plt.xticks(fontsize=10)
        plt.xticks(rotation= 30)
        plt.yticks(fontsize=10)
        plt.ylabel('Count',fontsize=15)
    
    num +=1
plt.show()

# %%
# Checking skewness in the target variable data
sns.histplot(newgrade['CGPA'],kde=True)
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
# Visualizing the 'CGPA' scores by histplot with a random subjects 
plt.figure(figsize=(10,10))
sns.histplot(data=newgrade, x="CGPA", hue="HS-101",multiple="layer")
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
# checking the outliers using boxplot
plt.figure(figsize=(20,15),facecolor='lightyellow')
x = 1
for col in newgrade :
    if x<=43:
        ax=plt.subplot(11,4,x)
        sns.boxplot(newgrade[col],color="r")
        plt.xlabel(col,fontsize=20)
        plt.yticks(rotation=180, fontsize=10)
    x +=1
plt.tight_layout()
plt.show()

# %% [markdown]
# There aren't any significant outliers present in the dataset.

# %% [markdown]
# # checking the skewness.

# %%
#Check whether data is skewed
newgrade.skew()
# Out:
# CY-105       0.982144
# HS-105/12    0.324183
# MT-111       0.484906
# CS-106       0.639845
# EL-102       0.501161
# EE-119       0.574880
# ME-107       0.108385
# CS-107       0.414846
# HS-205/20    0.897186
# MT-222       0.193993
# EE-222       0.759105
# MT-224       0.430480
# CS-210       0.723967
# CS-211       0.116085
# CS-203       0.274205
# CS-214       0.013129
# EE-217       0.724325
# CS-212       0.414872
# CS-215       0.163631
# MT-331       0.627721
# EF-303       0.383655
# HS-304       0.544843
# CS-301       0.415084
# CS-302       0.601788
# TC-383       0.331652
# MT-442       0.869952
# EL-332       0.459160
# CS-318       0.356504
# CS-306       0.424753
# CS-312       0.442525
# CS-317       0.140692
# CS-403       0.618339
# CS-421       0.179508
# CS-406       1.522703
# CS-414       1.292931
# CS-419       0.506748
# CS-423       0.526550
# CS-412       1.329362
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# ...

# %%
plt.figure(figsize=(15,20))
x = 1

for columns in newgrade:
    if x <= 43:
        ax= plt.subplot(11,4,x)
        sns.distplot(newgrade[columns],color="red")
        plt.xlabel(columns)
        x+=1
plt.show()

# %% [markdown]
# Skewness is not noticeable in the dataset.

# %%
newgrade.corr()
# Out:
#              CY-105  HS-105/12    MT-111    CS-106    EL-102    EE-119  \
# CY-105     1.000000   0.510123  0.538380  0.378223  0.447539  0.467250
# HS-105/12  0.510123   1.000000  0.494731  0.499093  0.360304  0.400303
# MT-111     0.538380   0.494731  1.000000  0.500729  0.555895  0.409161
# CS-106     0.378223   0.499093  0.500729  1.000000  0.338645  0.269895
# EL-102     0.447539   0.360304  0.555895  0.338645  1.000000  0.448908
# EE-119     0.467250   0.400303  0.409161  0.269895  0.448908  1.000000
# ME-107     0.464418   0.320137  0.471685  0.281233  0.461690  0.572964
# CS-107     0.481277   0.540405  0.488977  0.422237  0.454290  0.390834
# HS-205/20  0.261281   0.179766  0.328574  0.115335  0.368922  0.339430
# MT-222     0.485371   0.459571  0.499415  0.362293  0.451722  0.455881
# EE-222     0.394398   0.379369  0.393494  0.185709  0.402440  0.444792
# MT-224     0.437339   0.392068  0.567848  0.383993  0.482855  0.418834
# ...

# %%
# Visualizing Correlation in heatmap
plt.figure(figsize=(50,30))
sns.heatmap(newgrade.corr(),annot=True)
# Out:
# <Axes: >

# %%
newgrade.corr()['CGPA'].sort_values(ascending = False)
# Out:
# CGPA         1.000000
# Seat No.     0.054342
# CS-414      -0.384003
# CS-312      -0.458019
# HS-205/20   -0.460525
# CS-412      -0.466512
# CS-406      -0.474419
# EF-303      -0.485478
# MT-331      -0.508428
# CS-423      -0.520968
# CS-106      -0.534995
# HS-101      -0.537170
# CS-403      -0.544543
# HS-304      -0.557912
# CS-318      -0.566393
# TC-383      -0.572329
# EE-222      -0.575335
# MT-442      -0.582592
# CS-105      -0.613169
# HS-105/12   -0.613989
# CS-107      -0.615309
# CS-211      -0.628070
# CS-421      -0.633001
# CS-419      -0.641804
# EL-102      -0.642262
# CS-212      -0.642878
# CS-203      -0.644191
# EE-119      -0.646829
# EE-217      -0.655993
# MT-222      -0.656320
# CY-105      -0.658282
# ME-107      -0.663023
# PH-121      -0.663135
# CS-301      -0.664117
# MT-224      -0.692696
# CS-302      -0.696112
# CS-306      -0.708299
# EL-332      -0.729609
# MT-111      -0.730095
# CS-215      -0.730460
# CS-214      -0.733848
# ...

# %%
plt.figure(figsize = (22,10))
newgrade.corr()['CGPA'].sort_values(ascending = False).drop(['CGPA']).plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize = 15)
plt.ylabel('Target',fontsize = 15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %% [markdown]
# # Checking the outliers

# %%
#removing the outliers using zscore
from scipy.stats import zscore
all_features = newgrade.drop('CGPA', axis=1)
z=np.abs(zscore(all_features))

z.shape
# Out:
# (571, 42)

# %%
threshold = 3   
print(np.where(z>3))
# Out:
# (array([ 60,  60,  60,  91, 137, 143, 281, 281, 288, 340, 340, 352, 352,
#        382, 387, 387, 410, 423, 424, 432, 446, 447, 447, 453, 453, 454,
#        454, 454, 509, 513, 516, 516, 521, 522, 522, 527, 543, 543, 550,
#        550, 557, 560, 563, 570]), array([ 0,  8, 16, 12,  0,  0,  8, 12,  8, 21, 34, 21, 34, 34, 34, 37, 34,
#        34, 34, 37, 33, 33, 34, 33, 37, 33, 34, 35, 33, 37, 33, 37, 33, 33,
#        37, 37, 33, 37, 34, 37, 34, 34, 35, 33]))

# %% [markdown]
# # Removing Outliers

# %%
df= newgrade[(z<3).all(axis=1)]

print("Old DataFrame ",newgrade.shape)
print("New DataFrame ",df.shape)
print("Total Dropped Rows are ",newgrade.shape[0]-df.shape[0])
# Out:
# Old DataFrame  (571, 43)
# New DataFrame  (541, 43)
# Total Dropped Rows are  30

# %%
Data_Loss = print("Data Loss Percentage :",((newgrade.shape[0]-df.shape[0])/newgrade.shape[0])*100)
# Out:
# Data Loss Percentage : 5.253940455341506

# %% [markdown]
# # Splitting the dataset

# %%
#Splitting the datset into features and target values.
x = df.drop(['CGPA'],axis =1)

# %%
x
# Out:
#      CY-105  HS-105/12  MT-111  CS-106  EL-102  EE-119  ME-107  CS-107  \
# 0         8          6       8       9       8       5       8       8
# 1        10          9       5       9       0      10       9       4
# 2         0          5       4       5       4       2       2       5
# 3        10          9       9      10       8       9       7       9
# 4         2          4       0       2       4       0       2       6
# ..      ...        ...     ...     ...     ...     ...     ...     ...
# 565       9          8       2       9       2       2       2       0
# 566       0          2       1       2       2       1       4       1
# 567       0          0       0       0       2       0       0       1
# 568       2          4       0       0       0       0       3       1
# 569       9          0       9       5       8       5       8       1
#
#      HS-205/20  MT-222  ...  CS-421  CS-406  CS-414  CS-419  CS-423  CS-412  \
# ...

# %%
y = df['CGPA']

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 565    0.800
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# Name: CGPA, Length: 541, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model  import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor , AdaBoostRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection  import GridSearchCV

# %%
Model= [LinearRegression(),RandomForestRegressor(),KNeighborsRegressor(),DecisionTreeRegressor(), SVR(),GradientBoostingRegressor(),AdaBoostRegressor()]

# %%
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .20, random_state=i)
    for m in Model:
        maxScore = 0
        maxRs = 0
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        score = r2_score(y_test,pred)
        if score>maxScore:
            maxScore = score
            maxRs=i
print("Best Accuracy is:", maxScore, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.8980951634262391 on Random State: 49

# %%
#Now splitting the dataset into the Training set and test set
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=49)

# %%
print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (432, 42)
# Training target vector size: (432,)
# Test feature matrix size: (109, 42)
# Test target vector size: (109,)

# %%
#Using PCA (Principal component analysis)for dimensionality reduction
from sklearn.decomposition import PCA
pca=PCA(n_components=0.90)
x_train=pca.fit_transform(x_train)
x_test =pca.transform(x_test)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9886806415799009

# %%
from sklearn.model_selection import cross_val_score
for m in Model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print('--------------------',m,'-----------------------')
    print(f" R2 score is: {r2_score(y_test,predm)*100}")
    print ('\n','mean_absolute_error:','\n',mean_absolute_error(y_test,predm))
    print ('\n','mean_squared_error:','\n',mean_squared_error(y_test,predm))
    print ('\n','Root Mean Squared Error:','\n',np.sqrt(mean_squared_error(y_test,predm)))
    score = cross_val_score(m,x,y,cv=5)
    print('\n',f"Cross val score: {score.mean()*100}")
    print(f'\n Difference between R2 score and cross val score {(r2_score(y_test,predm)-score.mean())*100}')
    print('\n')
# Out:
# -------------------- LinearRegression() -----------------------
#  R2 score is: -0.3934998342686624
#
#  mean_absolute_error:
#  0.4897204915135964
#
#  mean_squared_error:
#  0.3424947847472709
#
#  Root Mean Squared Error:
#  0.5852305398279134
#
#  Cross val score: 91.24451143044276
#
#  Difference between R2 score and cross val score -91.63801126471142
#
#
# -------------------- RandomForestRegressor() -----------------------
#  R2 score is: -23.1380241130837
#
#  mean_absolute_error:
#  0.4987601834862386
#
#  mean_squared_error:
#  0.42008826400550475
#
#  Root Mean Squared Error:
#  0.6481421634221189
#
#  Cross val score: 90.49450937870918
#
#  Difference between R2 score and cross val score -113.63253349179287
#
#
# -------------------- KNeighborsRegressor() -----------------------
#  R2 score is: -1.8128329470917137
#
#  mean_absolute_error:
#  0.47391009174311927
#
#  mean_squared_error:
#  0.347336873027523
#
#  Root Mean Squared Error:
#  0.5893529273936993
#
# ...

# %% [markdown]
# Observation: SVR is best model for prediction

# %% [markdown]
# # HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
 #Hyperparameter tuning for Support Vector Regressor

params_svr = {'kernel':['linear', 'rbf', 'sigmoid'],
              'gamma':['scale','auto']}

Gridsvr = GridSearchCV(SVR(),params_svr)

Gridsvr.fit(x_train,y_train)

print(Gridsvr.best_params_)
# Out:
# {'gamma': 'scale', 'kernel': 'linear'}

# %%
model = SVR(gamma='scale',kernel = 'linear')
model.fit(x_train,y_train)
pred = model.predict(x_test)
print('R2 score: ',(r2_score(y_test,pred)*100))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred))
print('Mean Squared Error: ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score:  0.5990113068758074
# Mean Absolute Error:  0.48382410439509466
# Mean Squared Error:  0.33910880965718326
# Root Mean Squared Error:  0.5823304986493351

# %%
# Plotting Predicted vs Actual CGPA
plt.figure(figsize=(8,6))
plt.scatter(y_test,pred,color ='r')
plt.plot(y_test,y_test,color ='b')
plt.xlabel('Actual CGPA',fontsize = 14)
plt.ylabel('Predicted CGPA',fontsize =14)
plt.title('SVR',fontsize = 18)
plt.show()

# %%
#Saving the model using .pkl
import pickle

finalmodel = 'Grade_Prediction.pkl'
pickle.dump(model,open(finalmodel,'wb'))

# %%
load_model = pickle.load(open('Grade_Prediction.pkl','rb'))
result = load_model.score(x_test,y_test)
pred_test = load_model.predict(x_test)

print("SVR :",result*100,'%')
# Out:
# SVR : 0.5990113068758074 %

# %%
pd.set_option('display.max_rows',None)
pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T
# Out:
#      Predicted  Original
# 0     3.141574     2.602
# 1     3.074966     2.716
# 2     3.019461     2.648
# 3     3.156724     3.734
# 4     3.013774     3.585
# 5     3.021640     3.164
# 6     3.046150     2.806
# 7     2.944569     3.483
# 8     3.119574     3.019
# 9     3.060408     2.775
# 10    3.128365     3.405
# 11    3.171587     2.607
# 12    2.958608     2.793
# 13    3.055478     3.972
# 14    3.163312     3.029
# 15    3.067130     3.418
# 16    3.087535     3.820
# 17    3.090054     3.437
# 18    2.946667     3.475
# 19    3.029956     3.229
# 20    3.152107     3.272
# 21    2.986057     2.056
# 22    3.037885     3.593
# 23    2.980628     1.845
# 24    3.142549     3.878
# 25    3.025652     2.129
# 26    3.037382     2.595
# 27    2.963284     2.999
# 28    3.112350     1.949
# 29    3.096220     2.851
# 30    3.021236     3.373
# 31    3.100863     3.136
# 32    3.093698     2.557
# 33    3.024620     3.645
# 34    3.018731     3.425
# 35    3.092517     3.491
# ...
